# %%
import json

# %%
# Load simplify data
dataset_dir = "./dataset/simplify_json"
json_files = [dataset_dir + "/train_split.json", dataset_dir + "/valid_split.json"]
data_files = []
for json_file in json_files:
    with open(json_file, 'r') as f:
        data_files.append(json.load(f))
              
data_files[0][0]
# Out:
# {'Openness': 'low',
#  'Conscientiousness': 'high',
#  'Extraversion': 'high',
#  'Agreeableness': 'low',
#  'Neuroticism': 'high',
#  'Speaker': '童文洁',
#  'Utterance': '真巧'}

# %%
# covert big-5 ['Openness', 'Conscientiousness', 'Extraversion','Agreeableness', 'Neuroticism'] to 0:low 1:high
for i in range(len(data_files)):
    for j in range(len(data_files[i])):
        data_files[i][j]['label'] = [0 if data_files[i][j]['Openness'] == 'low' else 1,
                                     0 if data_files[i][j]['Conscientiousness'] == 'low' else 1,
                                     0 if data_files[i][j]['Extraversion'] == 'low' else 1,
                                     0 if data_files[i][j]['Agreeableness'] == 'low' else 1,
                                     0 if data_files[i][j]['Neuroticism'] == 'low' else 1]
data_files[1][0]
# Out:
# {'Openness': 'low',
#  'Conscientiousness': 'high',
#  'Extraversion': 'high',
#  'Agreeableness': 'high',
#  'Neuroticism': 'high',
#  'Speaker': '于春晓',
#  'Utterance': '怎么了',
#  'label': [0, 1, 1, 1, 1]}

# %%
# Get (X_train y_train), (X_valid, y_valid) from json file

X_train = []   # name, Utterance
y_train = []   # big-5
X_valid = []    # name, Utterance
y_valid = []    # big-5
speakers_train, speakers_valid = [],[]
for i in range(len(data_files[0])):
    X_train.append((data_files[0][i]['Speaker'], data_files[0][i]['Utterance']))
    y_train.append(data_files[0][i]['label'])
    speakers_train.append(data_files[0][i]['Speaker'])
speakers_train = list(set(speakers_train))
print("There are {} speakers in train_data" .format(len(speakers_train)))

for i in range(len(data_files[1])):
    X_valid.append((data_files[1][i]['Speaker'], data_files[1][i]['Utterance']))
    y_valid.append(data_files[1][i]['label'])
    speakers_valid.append(data_files[1][i]['Speaker'])
speakers_valid = list(set(speakers_valid))
print("There are {} speakers in valid_data" .format(len(speakers_valid)))

X_train[0]
# Out:
# There are 220 speakers in train_data
# There are 33 speakers in valid_data
# ('童文洁', '真巧')

# %%
y_train[0]
# Out:
# [0, 1, 1, 0, 1]

# %%
def combine_same_speaker_data(speakers, X, y):
    # combine same speaker data to one data and only keep different Utterance and one speaker name
    X_combine = []
    y_combine = []
    for speaker in speakers:
        X_combine.append({speaker:[]})
        y_combine.append({speaker:[]})



    for i in range(len(X)):
        for j in range(len(X_combine)):
            if X[i][0] in X_combine[j]:
                X_combine[j][X[i][0]].append(X[i][1])
                y_combine[j][X[i][0]].append(y[i])


    for i in range(len(y_combine)):
        for key in y_combine[i]:
            y_combine[i][key] = y_combine[i][key][0]
    return X_combine, y_combine

# %%
X_train_combined, y_train_combined = combine_same_speaker_data(speakers_train, X_train, y_train)
X_valid_combined, y_valid_combined = combine_same_speaker_data(speakers_valid, X_valid, y_valid)

# %%
len(y_valid_combined)
# Out:
# 33

# %%
y_valid_combined
# Out:
# [{'方依依': [1, 0, 1, 1, 0]},
#  {'唐鹏母亲': [0, 1, 0, 0, 1]},
#  {'戴娜': [1, 1, 0, 0, 0]},
#  {'苏青': [0, 1, 0, 1, 0]},
#  {'王珊': [1, 1, 1, 1, 0]},
#  {'刘栋': [0, 0, 1, 1, 1]},
#  {'薛素梅': [0, 1, 1, 0, 1]},
#  {'莫小康': [1, 0, 0, 1, 1]},
#  {'顾末易': [0, 1, 0, 0, 0]},
#  {'胡七星': [1, 1, 1, 1, 0]},
#  {'刘慧芸': [0, 1, 0, 1, 1]},
#  {'莫正源': [0, 0, 1, 1, 0]},
#  {'唐鹏': [1, 1, 1, 1, 0]},
#  {'苏珊': [1, 1, 1, 1, 0]},
#  {'杨桃': [0, 1, 1, 1, 1]},
#  {'方骏': [0, 1, 1, 1, 0]},
#  {'果长山': [1, 0, 1, 1, 0]},
#  {'傅沛': [0, 0, 1, 1, 1]},
#  {'彭凯旋': [0, 1, 1, 1, 0]},
#  {'焦阳': [1, 1, 1, 1, 0]},
#  {'冯兰芝': [0, 1, 1, 0, 1]},
#  {'司徒末': [1, 1, 1, 0, 1]},
#  {'白洁': [0, 1, 1, 0, 1]},
#  {'于春晓': [0, 1, 1, 1, 1]},
#  {'林君': [1, 1, 0, 0, 0]},
#  {'孙总': [0, 0, 1, 0, 0]},
#  {'那依': [0, 1, 1, 0, 0]},
#  {'果然': [0, 1, 0, 1, 0]},
#  {'段西风': [0, 1, 1, 1, 0]},
#  {'安娜': [0, 1, 1, 1, 1]},
#  {'袁大头': [1, 0, 1, 1, 0]},
#  {'叶珊': [0, 1, 0, 0, 1]},
#  {'王长水': [0, 1, 1, 1, 0]}]

# %%
# encoding=utf-8
import jieba
seg_list = jieba.cut("我来到北京清华大学", cut_all=False)
print("Default Mode: " + " ".join(seg_list))  # Accruate Mode
# Out:
# Default Mode: 我 来到 北京 清华大学

# %%
for speaker in X_valid_combined:
    for key in speaker:
        for i in range(len(speaker[key])):
            seg_list = jieba.cut(speaker[key][i], cut_all=False)
            speaker[key][i] = " ".join(seg_list)

# %%
X_valid_combined[0]
# Out:
# {'方依依': ['你 终于 肯 搭理 我 了',
#   '想结 就 结',
#   '想离 就 离',
#   '喜欢 就结 了',
#   '我 觉得 我们 两个 人 更 适合 当 哥们',
#   '我能 插句 话 吗',
#   '杀人犯 还 能 请 律师',
#   '就算 我 承认错误',
#   '你 也 得 给 我 张嘴 的 机会',
#   '第一',
#   '我 不是 诚心 要 瞒 着 你 的',
#   '我 知道 告诉 你 不会 同意 的',
#   '所以 我 必须 得 瞒 着 你',
#   '第二',
#   '离婚 也 没什么 的',
#   '我们 这次 婚姻关系 总共 维持 了 不到 两个 月',
#   '派出所 户籍 上 我 还 单身',
#   '神不知鬼不觉 得 也 不 影响 我 第二次 销售',
#   '第三',
#   '其实 我 这次 婚姻 还是 挺 美满 的',
#   '离婚 之前 我们 感情 挺 好',
#   '等会儿 你 是 我哥 又 不是 我爸',
#   '怎么 成亲 家 了',
#   '你 怎么 说 脏话',
#   '我 不 允许 你 侮辱 我 前夫',
#   '哥 我 知道 这次 是 我 不 对',
#   '我 做 错',
#   '你 不是 号称 京城 第一 媒婆 吗',
#   '你 现在 就 给 我 找 一个 去',
#   '咱 不要 开 宝马',
#   '也 不要 开 奔驰 的',
#   '咱要 一开 飞机 的',
#   '哥 我 知道 你 对 我 好',
#   '我 长大 了',
#   '你 操心 你 自个儿 这 光棍 在 打 下去 就 打出 包浆 来 了',
#   '你 给 我 拍出 一 嫂子 来 才 是 真的 本分',
#   '你别 动不动 到 那 缩头乌龟 往 你 这 世外桃源 里面 扎成 吗 人 唐僧 九九八十一 那才 修成 正果',
#   '离 个个 把 次 婚算 什么',
#   '干嘛',
#   '我 饿 了',
#   '给 我 弄 点 吃 的 去',
#   '你 给 我 画 一个',
#   '给 我 画 一 看看',
#   '你 不是 世家 吗',
#   '龙生龙 凤生凤 老鼠 的 孩子 还会 打洞',
#   '你 随便 给 我 画 一 看看   来',
#   '擅长 什么 写意 还是 写实',
#   '印象派 还是 抽象派',
#   '完 了   你 这 什么',
#   '你 这 小学 数学课 的 水平',
#   '你 给 我 评论 评论',
#   '要纸 吗',
#   '什么 时候',
#   '十男 九 痔 听说 过 吗',
#   '马桶 做久 了 容易 生 痔疮',
#   '什么 叫 你 的 创意',
#   '这 照片 是 我 拍 的',
#   '你 通过 我 的 照片 才 有 创意',
#   '给 我 什么 好处',
#   '多少 钱',
#   '你 这次 活儿干 下来 能 赚 多少 钱',
#   '你 这 人 真 逗',
#   '国外 这么 好 的 学校 您 不 去 念念 去 就 为 这点 钱 回国',
#   '合着 您 在 国外 不是 做 您 自个儿 的',
#   '你 让 人贩子 给 卖出去',
#   '不能',
#   '不 就 离个 婚',
#   '至少 你 还有 爸有 妈',
#   '我 都 不 知道 我 爸妈 长 什么样',
#   '你 才 孤儿   你们 全家 的 孤儿',
#   '凭 什么 瞧不起 我',
#   '你 算 老几 你 瞧不起 我',
#   '我 是不是 孤儿 怪 你 什么 事',
#   '王八蛋',
#   '这 是 你 想要 这种 感觉 吗',
#   '废话',
#   '没 看过 水平 来   我 去 我们 影棚 就 想 当 摄影师',
#   '结果 把 我 当 驴 使   什么 重',
#   '让 我 扛 什么',
#   '机器 还 没 摸 过',
#   '就 练 一 胳膊 肌肉',
#   '这 不 正好 有 这么 一个 机会 能 把 我 的 作品 发表 出去',
#   '这 就是 机遇',
#   '得 攥 紧 了',
#   '咱先 说好',
#   '我 不能 白给 你 干',
#   '你 得付 我 工钱',
#   '到时候 这 广告 出来 了',
#   '你 得 在 上面 加 一行 小字',
#   '行 了 知道 你 没 钱',
#   '先 打白条',
#   '我 先 把 话 说 在 前头',
#   '我 不是 你 的 员工',
#   '别 动不动 对 我 指手画脚 的',
#   '呼来唤去',
#   '到时候 别 耍赖',
#   '还 想 咬 人',
#   '不听话 就 得 拴着',
#   '放 你 干嘛   再 找 人 算账 去',
#   '落 我 手里 了',
#   '还 想 撒野',
#   '门 都 没有',
#   '尿 尿   急 吗',
#   '有 多 急',
#   '好 答应 我 三件 事 我 就 放 了 你',
#   '第一 再 不许 找 人家 麻烦',
#   '第二 广告费 这 事 交给 我',
#   '替 你 出头',
#   '不许 插手',
#   '第三',
#   '我 还 没想 好   等 我 想 好 以后 你 必须 无条件 服从',
#   '是 条 汉子',
#   '真 爷们',
#   '我 看看 是 你 狠 还是 我狠',
#   '怎么 有 香水 味儿',
#   '有 女人 来过',
#   '哥 你 有 情况',
#   '你 是不是 喝酒 了',
#   '一点 啤 的',
#   '知道 了',
#   '哥 我 能求 你件 事儿 吗',
#   '我 说 的 是 吧',
#   '照哥 你 这 暴脾气',
#   '你 早 跟 他们 拼 了',
#   '是不是',
#   '合着 我 说 这么 半天 你 一句 都 没 听 进去',
#   '你 这人 怎么 这样',
#   '你 今儿 怎么 了',
#   '魂不守舍 的',
#   '你 小时候 还 能 为了 我 跟 人家 打架',
#   '现在 你 就 看 你 亲 妹妹 受 欺负 你 就 不管 了',
#   '这 叫 震慑   哥',
#   '广告费 好几万',
#   '你 放心 这事 我 都 已经 安排 好 了',
#   '你 去 了 以后 你 就 只管 喷',
#   '把 他侃 晕 了   用 你 的 三寸不烂之舌   我 烦死 他们',
#   '其他 的 事 交给 我来 办',
#   '你 有 更好 的 办法 吗',
#   '你 就 忍心 看着 你 亲 妹妹 一宿 一宿 的 不 合眼',
#   '熬出来 的 创意 让 别人 去 剽窃 吗',
#   '我 现在 不 找 你',
#   '我 找 谁 去',
#   '你 就 忍心 看着 我 一个 身单力薄 的 弱女子 去 跟 人 讨说法 吗',
#   '你 舍得 吗',
#   '这 怎么 能 是 破 创意',
#   '他们 盗取 了 我 的 灵魂',
#   '我求 你 了   我 现在 就 指着 你 给 我 撑腰 了',
#   '你 不 帮 我 我 怎么办',
#   '那 就 不怕 了',
#   '我 给 你 找 一帮 武林高手',
#   '人家',
#   '人家 是 合法 的 专业 的 保安',
#   '就算 真打 起来 了',
#   '你 先 跑 我 断后',
#   '我求 你 了   你 今天 穿 那么 帅',
#   '跟 夏威夷 似的',
#   '真的',
#   '为什么 用 我 的 钱 我 没 钱',
#   '力度 行 吗',
#   '舒服 吗',
#   '我错 了',
#   '我 不该 自己 跑',
#   '这么 干 不 仗义',
#   '可 你 又 不是 不 知道',
#   '我 从小 就 害怕 警察',
#   '你 为什么 不 跑',
#   '那 你 赖 谁 啊',
#   '不 知道',
#   '我 不是 姑娘 了',
#   '我 都 离 完婚 了',
#   '我错 了 还 不行 吗',
#   '要 想成 大事 就 得 挨 得 住 摔打',
#   '听说 过 悬梁刺股 吗',
#   '那 悬 的 是 自己 的 脑袋',
#   '刺 的 是 自己 的 屁股',
#   '没事 得 对 自己 狠',
#   '不是 对 别人',
#   '又 不是 拉 不 出去',
#   '反正 现在 我 也 没 工作 了',
#   '咱们 两个 人 难兄难弟 伙着 干',
#   '就 凭 我 的 聪明才智',
#   '外 加上 你 的 那 一 丢 丢 的 小 机灵',
#   '早晚 能 成功',
#   '允许 你 打白条',
#   '不 就 一破 马桶 广告 吗',
#   '有 什么 了不起 的 我 还 不 稀罕 呢',
#   '回头 咱们 俩 功成名就 了',
#   '说 咱们 两个 人 在 马桶 里面 发的家 多 寒颤',
#   '我哥 说 了',
#   '长安街 宽   该 堵 的 时候 他 也 堵',
#   '关键 得 看 怎么 疏通',
#   '化 悲愤 为 力量',
#   '反正 底线 就是 饿不死',
#   '待会 我 回去 把 我 拍 的 那些 照片 全都 得 拿来',
#   '咱们 两个 人多 做 几套 方案',
#   '往大 公司 里边 投',
#   '没准 就 能 遇上 几个 瞎了眼 的',
#   '到时候 咱们 俩 一块 跟 人 谈 去',
#   '我主 喷   就 说 你 是 、',
#   '载誉归来 的 华人 设计师',
#   '你 不是 英语 好 吗',
#   '你 负责 拿 英语 把 他们 侃晕 了',
#   '他们 现在 就认 这个',
#   '蒙 不好 那才 叫 蒙蒙 的 好',
#   '那 叫 营销',
#   '什么 都 不 懂',
#   '艺术家 呢   傻 吧 你',
#   '那 你 交',
#   '什么 意思',
#   '我 不管 你 要 工资 已经 够 便宜 你 的',
#   '蹬 鼻子 上 脸 是 吧',
#   '想 都 甭想',
#   '我 告诉 你 那 钱 是 给 我 哥留 着 娶媳妇 用 的',
#   '谁 惦记 跟 谁 拼命',
#   '干嘛 你 要 给 他 介绍',
#   '告诉 你',
#   '趁早 打消 主意',
#   '一个 大老爷们 就 应该 想 办法 出去 挣钱 去',
#   '实在 不行 回 保安 公司 做 兼职 得',
#   '要 不 我 给 你 支 一招',
#   '你 还有 2000 块钱',
#   '买 一千 注 彩票',
#   '要是 中 了   你 就 发达 了',
#   '要是 没中 你 就 把 彩票 搓成 一根 绳',
#   '把 自个 勒死',
#   '你 在 北京 不是 有家 吗',
#   '你 回家 要点 不 就 完 了 吗',
#   '你们 家 都 供 得 起 你 出国 应该 不差 这点 钱 了',
#   '这 还 不到 万不得已',
#   '当务之急 是 先想 办法 弄点 钱',
#   '先 把 房租 给 交上',
#   '咱开 的 是 广告公司',
#   '不是 摆地摊 吆喝 卖 13 香 的',
#   '得 有 个 办公 地点',
#   '没钱 了 找 你 爸妈 要 去',
#   '实在 不行 你 回家 看看 你们 家有 什么 东西 值钱',
#   '倒腾 点 拿 出来 卖 了',
#   '我 又 没爹 没妈 的',
#   '就 我哥 那 点破 东西 又 不值钱',
#   '你 先 给 我 列个 单子',
#   '看 你们 家 都 有 什么 值钱 的 东西',
#   '咱们 先 把 它 放在 典当行',
#   '回头 有钱 再 把 它 赎 出来',
#   '我 告诉 你',
#   '既然 我 是 总经理',
#   '这事 就 得 听 我 的',
#   '就 得 这么 办',
#   '难不成 你 还是 总经理',
#   '凭 什么 就 你 这样 的 你 经理 得 了 谁',
#   '我 搞 的 是 技术',
#   '掌握 的 是 公司 的 生命',
#   '光有 魂 那 是 鬼',
#   '还有 你 欠 我 那 钱',
#   '行 啊 你',
#   '跟 我 混 的 嘴皮子 功夫 见长',
#   '行',
#   '咱俩 比试 比试',
#   '谁 本事 大 谁 当 总经理',
#   '当 领导 嘛',
#   '就 得 有 泰山 崩于 前 而 面不改色',
#   '得 胆大心细',
#   '敢 跟 我 比 谁 胆大',
#   '那 是 文盲',
#   '跟 这儿 等 着 我',
#   '我 现在 回趟 家',
#   '跟 这儿 等 着',
#   '我 觉得 你 这 两天 不太 对劲',
#   '说 谁 把 你 小 心肝 给 伤 了',
#   '说 说',
#   '别 绕弯子   瞎 扯淡',
#   '我 还 不 了解   你 就是 想 女人 了',
#   '说 说到底 有 什么 心事',
#   '咱妈 是 长 头发 短 头发',
#   '我 自己 有',
#   '行行 行摸够 没有',
#   '合着 你 全用 洗衣粉 给 我 洗头  ',
#   '我 觉得 还是 我 把 你 给 耽误 了   要是 没有 我',
#   '梁静茹',
#   '什么 不是 你',
#   '可惜 不是 你',
#   '幸亏 不是   你 也 想 的 出来',
#   '来   干 一个',
#   '我 也 不 知道 最近 怎么 了',
#   '特别 疲惫',
#   '看见 吃 的 就 拔 不动 腿',
#   '我 不是 得 甲亢 了 吧',
#   '要不然 就让 你们 公司 给 愁 的',
#   '我 这 总经理 太 日理万机 了',
#   '赶紧 回去 问 你 妈 要钱 去',
#   '赶紧 把 那 房租 给 交上',
#   '你 心疼 你 亲妈',
#   '那 就 问 你 后妈 要钱',
#   '1 爹 2 妈',
#   '在家 你 是 独苗',
#   '要点 钱 还 不分 分钟 的 事',
#   '我 倒 是 想 懂 哪 给 我 找 爹 找 妈 去',
#   '要不然 你 就 回头 看看 你们 家 还有 什么 值钱 的 东西',
#   '拿 出来 当 了 去',
#   '等 有钱 了 再 赎回 来',
#   '这算 民间 借贷',
#   '不算 监守自盗',
#   '你 爸 不是 著名画家 吗',
#   '你 回去 看看',
#   '你 爸 那 一幅 画能 卖 多少 钱',
#   '实在 不行',
#   '你 顺 两幅 回来',
#   '不过 怎么样',
#   '你 能 临摹 造假',
#   '能卖 多少 钱',
#   '八九千 万 我 吃 什么 煎饼果子',
#   '我开 什么 广告公司',
#   '我 直接 趟 钱 上 过 不 就 完 了 吗',
#   '不行   这钱 太多 了',
#   '不会 砸死 我 吧',
#   '你 能 花 很 长时间 的 行 吗',
#   '你 先 把 房租 给 交上',
#   '再 把 那 两台 咔 咔响 这 电脑 给 换 了',
#   '不 还 剩下 点能 撑 到 咱们 接下 个活 肯定 没 问题',
#   '这事 就 这么 定 了',
#   '赶紧 去 吧',
#   '多 新鲜   你 儿子 偷爹 不算 贼',
#   '我要 跟 你 一块 去 了 我 就 成 教唆犯 了',
#   '这险 不能 冒',
#   '这么 多年 你 还 能 记得',
#   '舍不得 吃 了',
#   '留着 慢慢 吃',
#   '那 也 不吃 了',
#   '晚上 吃 胖',
#   '你 才 嫁不出去',
#   '真 讨厌',
#   '我 刚才 都 睡着 了',
#   '你 把 我 和 醒 了',
#   '你 知道 吗',
#   '我 做 了 梦',
#   '梦见 咱妈 那 一头 乌黑 的 长 头发',
#   '我见 过 照片',
#   '你 见 过 了不起',
#   '你 有 吗',
#   '你家 这么 大 呢   皇宫 啊 这 是   太牛 了   这几居',
#   '这是   我 的 妈呀',
#   '这 就是 你家',
#   '你们 太 腐败 了',
#   '我 告诉 你',
#   '好 啊   这么 大一 电视机   莫 小康',
#   '你 真行',
#   '我 说 赖 在 这 不 出去 了 呢',
#   '我 也 赖 着 不 出门 了',
#   '那么 大 房间 你 开 空调 费 多少 电',
#   '都 有 什么 啊',
#   '我 得 自己 挑',
#   '太 腐败 了',
#   '莫 小康   你 住 着 豪宅',
#   '你们 家 原来 这么 有钱',
#   '你 还 交不起 房租',
#   '你 给 我 装穷 是 吧',
#   '这是 冰箱   双开门 的',
#   '我 的 天 哪',
#   '我 告诉 你 这 比 我们 家 大衣柜 可多大',
#   '一样 一个 都 尝尝',
#   '天 哪 有钱人 太 会 享受 了',
#   '你们 娘俩 为什么 放 那么 多 吃 的   对抗 世界末日 啊',
#   '这要 地震 砸 里头   够吃 半年 的',
#   '办 什么 正事',
#   '莫 小康',
#   '你 住 着 豪宅 开 什么 广告公司',
#   '这要 把 房子 卖 了 够 环游世界 好几圈 了 都',
#   '都 一样',
#   '想 什么 办法   我 还 干什么 活',
#   '我 得 享受 享受',
#   '这 是 你 屋   林哈   夫   你家 连 这个 都 有',
#   '我 以为 这种 相机 只有 电影 里面 才 有 的',
#   '我 今天 见 着 真机 了',
#   '我 的 天',
#   '禄来   I35T',
#   '你 知道 吗',
#   '在 那个 年代 这 是 最 迷你 的 了',
#   '徕 卡   还是 限量版 的',
#   '你 知道 这个 多少 钱 吗',
#   '行 啊 你   莫 小康',
#   '你 怎么 不早 带 我 来 这 啊',
#   '玛米亚 C33   这 简直 就是 尤物',
#   '这是',
#   '拿 玩儿',
#   '你 知道 吗',
#   '这加 起来 好几十万   莫 小康',
#   '我要 给 你 弄坏了',
#   '我 两 肾 卖 了 我 都 买不起',
#   '看 成色 少说 也 得 小 4 万',
#   '你 个 败家 玩意儿   这 怎么 能卖',
#   '是 艺术品',
#   '你 懂吗',
#   '艺术品',
#   '你 听 着   这 就是 世界 上 最 美丽 的 音乐 了',
#   '你 看 我 啊',
#   '你 看 我 像不像 有 一个 电影 叫 皮相',
#   '猎影 里面 那个',
#   '妮可 基曼德',
#   '什么 玩意儿 这是',
#   '你们 家 燃料 不是 花钱买 的',
#   '就 这 水平 还 想 从 你 爸 身上 抠 钱',
#   '我 也 能看懂   你 是 两只 烤 白薯   吧唧   拍 在 了 地上',
#   '然后 跑 过 一只 狗来 一通 乱 刨',
#   '再 磕 俩 生 鸡蛋',
#   '完 了',
#   '我 只会用 电脑 做图',
#   '我 哪会 用笔',
#   '你 这个 太 不像样 了',
#   '要 不 这样',
#   '我 手机 里面 拍 了 不少 不错 的 照片',
#   '你 把 它 传到 电脑 上',
#   '用 PS 修一修',
#   '修成 油画 的 效果',
#   '比 着 葫芦 画瓢 总 可以 吧',
#   '我 怎么 摊上 你 这么 一个 合伙人',
#   '你 还 真当 自个儿 是 海归 艺术家 了',
#   '我 看 咱俩 趁早 散伙',
#   '我 不想 跟 你 在 这 耽误时间 了',
#   '赶紧   还 钱',
#   '还 钱   把 欠 我',
#   '那钱 还 了',
#   '就 你 这样   你 也 就 会 开 着 大 奔 撞 撞 我 这 无知 少女',
#   '甭 废话 赶紧 还 钱',
#   '你 甭 废话 了 成 吗',
#   '你 倒 是 不愁吃 不愁穿',
#   '就 凭 你 爸 那些 画',
#   '外加 你 住 的 这些 豪宅',
#   '将来 可 都 是 你 的',
#   '你 什么 都 不用 干',
#   '躺 在 床上 你 植物 人能 活到 下 半辈子',
#   '我 可 没 那 资本 陪 你 坐吃山空',
#   '反应 变快 了',
#   '真的',
#   '你 太 识货 了',
#   '行行好 我 马上 就 去 办',
#   '可 你 别蒙 我们   我们 可 吃 过 亏 的',
#   '好好 行',
#   '我 马上 去 办   再 联系',
#   '再见',
#   '有家 广告公司 看上 咱 的 创意 了',
#   '他出 了 几条 意见 让 咱 修改 好 了 就 给 他 签合同 去',
#   '就是 优 乳酸 那个',
#   '唉 别   别别',
#   '你 赶紧 开 电脑',
#   '意见 都 在 邮箱   赶紧 给 人发 过去',
#   '你 这 垃圾 都 扔出去']}
